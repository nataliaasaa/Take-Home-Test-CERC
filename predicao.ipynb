# %% [markdown]
# ### Predição de Risco de Crédito

# %%
import pickle
from pycaret.classification import load_model, predict_model
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
def load_models():

    ml_model = load_model("models/finalized_model_ml")

    with open("models/label_encoder.pkl", "rb") as f:
        label_encoder = pickle.load(f)

    with open("models/pickled-model-regras_financeiras.pkl", "rb") as f:
        binary_model = pickle.load(f)

    return ml_model, label_encoder, binary_model

ml_model, label_encoder, binary_model = load_models()
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
df = pd.read_csv("data/corporate_rating_evaluation.csv")

features_ml = df.drop(columns=["Unnamed: 0", "Name", "Symbol", "Rating", "Rating Agency Name", "Date"], errors="ignore")

predictions_ml = predict_model(ml_model, data=features_ml)

df["ml_predicted_class"] = predictions_ml['prediction_label']

df["ml_predict_label"] = label_encoder.inverse_transform(df["ml_predicted_class"])

# %%
# Os scores são normalizados e combinados em um Financial Health Score.


df["liquidity_score"] = (
    0.4 * df["currentRatio"] +
    0.3 * df["quickRatio"] +
    0.3 * df["cashRatio"]
)

df["profitability_score"] = (
    0.25 * df["grossProfitMargin"] +
    0.25 * df["operatingProfitMargin"] +
    0.25 * df["netProfitMargin"] +
    0.25 * df["returnOnAssets"]
)

df["leverage_score"] = (
    0.6 * df["debtRatio"] +
    0.4 * df["debtEquityRatio"]
)

df["cashflow_score"] = (
    0.5 * df["operatingCashFlowPerShare"] +
    0.5 * df["freeCashFlowPerShare"]
)

score_cols = [
    "liquidity_score",
    "profitability_score",
    "leverage_score",
    "cashflow_score"
]

scaler = StandardScaler()
df[score_cols] = scaler.fit_transform(df[score_cols])

df["financial_health_score"] = (
    0.3 * df["liquidity_score"] +
    0.3 * df["profitability_score"] -
    0.2 * df["leverage_score"] +
    0.2 * df["cashflow_score"]
)

# %% [markdown]
# #####  Modelo binário + regras financeiras

# %%
df["risk_probability"] = binary_model.predict_proba(
    df[score_cols + ["financial_health_score"]]
)[:, 1]

def rule_based_risk(row):
    flags = 0
    if row["currentRatio"] < 1:
        flags += 1
    if row["debtRatio"] > 0.6:
        flags += 1
    if row["returnOnAssets"] < 0:
        flags += 1
    if row["operatingCashFlowPerShare"] < 0:
        flags += 1
    return flags

df["rule_flags"] = df.apply(rule_based_risk, axis=1)

df["final_risk_score"] = (
    0.7 * df["risk_probability"] +
    0.3 * (df["rule_flags"] / df["rule_flags"].max())
)

df["risk_bucket"] = pd.cut(
    df["final_risk_score"],
    bins=[0, 0.33, 0.66, 1],
    labels=["Low", "Medium", "High"]
)

# %% [markdown]
# ##### Resultado final

# %%
ml_to_bucket = {
    "Lowest Risk": "Low",
    "Low Risk": "Low",
    "Medium Risk": "Medium",
    "High Risk": "High",
    "Highest Risk": "High"
}

df["ml_risk_bucket"] = df["ml_predict_label"].map(ml_to_bucket)

df["risk_disagreement"] = df["ml_risk_bucket"] != df["risk_bucket"]

# %%
final_cols = [
    "Name",
    "ml_predict_label",
    "risk_probability",
    "rule_flags",
    "final_risk_score",
    "risk_bucket",
    "risk_disagreement"
]

final_cols = [c for c in final_cols if c in df.columns]


def highlight_disagreement(row):
    if row["risk_disagreement"]:
        return ["background-color: #ffcccc"] * len(row)
    else:
        return [""] * len(row)

styled_df = df[final_cols].style.apply(highlight_disagreement, axis=1)
styled_df
# Out:
# <style type="text/css">
# #T_228de_row0_col0, #T_228de_row0_col1, #T_228de_row0_col2, #T_228de_row0_col3, #T_228de_row0_col4, #T_228de_row0_col5, #T_228de_row0_col6, #T_228de_row1_col0, #T_228de_row1_col1, #T_228de_row1_col2, #T_228de_row1_col3, #T_228de_row1_col4, #T_228de_row1_col5, #T_228de_row1_col6, #T_228de_row2_col0, #T_228de_row2_col1, #T_228de_row2_col2, #T_228de_row2_col3, #T_228de_row2_col4, #T_228de_row2_col5, #T_228de_row2_col6, #T_228de_row5_col0, #T_228de_row5_col1, #T_228de_row5_col2, #T_228de_row5_col3, #T_228de_row5_col4, #T_228de_row5_col5, #T_228de_row5_col6, #T_228de_row8_col0, #T_228de_row8_col1, #T_228de_row8_col2, #T_228de_row8_col3, #T_228de_row8_col4, #T_228de_row8_col5, #T_228de_row8_col6, #T_228de_row9_col0, #T_228de_row9_col1, #T_228de_row9_col2, #T_228de_row9_col3, #T_228de_row9_col4, #T_228de_row9_col5, #T_228de_row9_col6, #T_228de_row11_col0, #T_228de_row11_col1, #T_228de_row11_col2, #T_228de_row11_col3, #T_228de_row11_col4, #T_228de_row11_col5, #T_228de_row11_col6, #T_228de_row12_col0, #T_228de_row12_col1, #T_228de_row12_col2, #T_228de_row12_col3, #T_228de_row12_col4, #T_228de_row12_col5, #T_228de_row12_col6, #T_228de_row13_col0, #T_228de_row13_col1, #T_228de_row13_col2, #T_228de_row13_col3, #T_228de_row13_col4, #T_228de_row13_col5, #T_228de_row13_col6, #T_228de_row15_col0, #T_228de_row15_col1, #T_228de_row15_col2, #T_228de_row15_col3, #T_228de_row15_col4, #T_228de_row15_col5, #T_228de_row15_col6, #T_228de_row16_col0, #T_228de_row16_col1, #T_228de_row16_col2, #T_228de_row16_col3, #T_228de_row16_col4, #T_228de_row16_col5, #T_228de_row16_col6, #T_228de_row18_col0, #T_228de_row18_col1, #T_228de_row18_col2, #T_228de_row18_col3, #T_228de_row18_col4, #T_228de_row18_col5, #T_228de_row18_col6, #T_228de_row19_col0, #T_228de_row19_col1, #T_228de_row19_col2, #T_228de_row19_col3, #T_228de_row19_col4, #T_228de_row19_col5, #T_228de_row19_col6, #T_228de_row20_col0, #T_228de_row20_col1, #T_228de_row20_col2, #T_228de_row20_col3, #T_228de_row20_col4, #T_228de_row20_col5, #T_228de_row20_col6, #T_228de_row21_col0, #T_228de_row21_col1, #T_228de_row21_col2, #T_228de_row21_col3, #T_228de_row21_col4, #T_228de_row21_col5, #T_228de_row21_col6, #T_228de_row22_col0, #T_228de_row22_col1, #T_228de_row22_col2, #T_228de_row22_col3, #T_228de_row22_col4, #T_228de_row22_col5, #T_228de_row22_col6, #T_228de_row24_col0, #T_228de_row24_col1, #T_228de_row24_col2, #T_228de_row24_col3, #T_228de_row24_col4, #T_228de_row24_col5, #T_228de_row24_col6, #T_228de_row25_col0, #T_228de_row25_col1, #T_228de_row25_col2, #T_228de_row25_col3, #T_228de_row25_col4, #T_228de_row25_col5, #T_228de_row25_col6, #T_228de_row28_col0, #T_228de_row28_col1, #T_228de_row28_col2, #T_228de_row28_col3, #T_228de_row28_col4, #T_228de_row28_col5, #T_228de_row28_col6, #T_228de_row29_col0, #T_228de_row29_col1, #T_228de_row29_col2, #T_228de_row29_col3, #T_228de_row29_col4, #T_228de_row29_col5, #T_228de_row29_col6, #T_228de_row31_col0, #T_228de_row31_col1, #T_228de_row31_col2, #T_228de_row31_col3, #T_228de_row31_col4, #T_228de_row31_col5, #T_228de_row31_col6, #T_228de_row32_col0, #T_228de_row32_col1, #T_228de_row32_col2, #T_228de_row32_col3, #T_228de_row32_col4, #T_228de_row32_col5, #T_228de_row32_col6, #T_228de_row36_col0, #T_228de_row36_col1, #T_228de_row36_col2, #T_228de_row36_col3, #T_228de_row36_col4, #T_228de_row36_col5, #T_228de_row36_col6, #T_228de_row37_col0, #T_228de_row37_col1, #T_228de_row37_col2, #T_228de_row37_col3, #T_228de_row37_col4, #T_228de_row37_col5, #T_228de_row37_col6, #T_228de_row39_col0, #T_228de_row39_col1, #T_228de_row39_col2, #T_228de_row39_col3, #T_228de_row39_col4, #T_228de_row39_col5, #T_228de_row39_col6, #T_228de_row42_col0, #T_228de_row42_col1, #T_228de_row42_col2, #T_228de_row42_col3, #T_228de_row42_col4, #T_228de_row42_col5, #T_228de_row42_col6, #T_228de_row43_col0, #T_228de_row43_col1, #T_228de_row43_col2, #T_228de_row43_col3, #T_228de_row43_col4, #T_228de_row43_col5, #T_228de_row43_col6, #T_228de_row49_col0, #T_228de_row49_col1, #T_228de_row49_col2, #T_228de_r ...

# %%
agreement_summary = (df["risk_disagreement"].map({True: "Discordam", False: "Concordam"}).value_counts())
print("Total de casos:", len(df))
print("Casos que concordam:", int(agreement_summary.get("Concordam", 0)))
print("Casos que discordam:", int(agreement_summary.get("Discordam", 0)))
# Out:
# Total de casos: 406
# Casos que concordam: 164
# Casos que discordam: 242

# %%
df.to_csv("data/credit_risk_prediction.csv")
